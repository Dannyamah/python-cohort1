# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Basic Setup

# %%
student = ['daniel', 'alfred', 'amah', 'divine', 'ruth', 'george']
scores = [80, 90, 70, 60, 85, 74]

# %% [markdown]
# ### Line Plot

# %%
plt.plot(student, scores, color = 'blue')

plt.title('Student Test Scores')

plt.xlabel('Students Name')
plt.ylabel('Scores')
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
plt.scatter(student, scores, color = 'red')
plt.title('Student Test Scores')
plt.xlabel('Students')
plt.ylabel('Scores')
plt.show()

# %% [markdown]
# ### Bar Plot

# %%
plt.bar(student, scores, color = 'green')
plt.title('Student Test Scores')
plt.xlabel('Students')
plt.ylabel('Scores')
plt.show()

# %% [markdown]
# ### Histogram

# %%
plt.hist(scores, color = 'purple')
plt.title('Student Test Scores')
plt.xlabel('Students')
plt.ylabel('Scores')
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.bar(student, scores)
plt.title('Student Test Scores')
plt.xlabel('Students')
plt.ylabel('Scores')
plt.show()

# %% [markdown]
# ### Seaborn
# Easy tool in Python that helps you draw pretty picture (called plots) of your data. Built on top of matplotlib, making graphs look nice and imple to create for beginners. It turns number into color, colorful picture so you can see pattern fast

# %%
import seaborn as sns
import pandas as pd

# %% [markdown]
# ### Basic Setup

# %%
student = ['daniel', 'alfred', 'amah', 'divine', 'ruth', 'george']
scores = [80, 90, 70, 60, 85, 74]

data = pd.DataFrame({
        'Students': student, 
        'Scores': scores
})

data
# Out:
#   Students  Scores
# 0   daniel      80
# 1   alfred      90
# 2     amah      70
# 3   divine      60
# 4     ruth      85
# 5   george      74

# %% [markdown]
# ### Line Plot

# %%
sns.lineplot(x='Students', y='Scores', data=data, color='blue')
plt.title('Student Test Scores')
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
sns.scatterplot(x = "Students", y = 'Scores', data = data, color = 'red')

plt.title('Students Test Scores')
plt.show()

# %% [markdown]
# ### Bar Plot

# %%
sns.barplot(x = "Students", y = "Scores", data = data, color = 'green')

plt.title("Student Test Score")
plt.show()

# %% [markdown]
# ### Histogram

# %%
sns.histplot(data = data, x = "Scores", color = 'purple')

plt.title("Student Test Score")
plt.show()

# %% [markdown]
# ### Visualizing Web3 Token Transfer Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv(
    '../web3_token_transfers.csv', parse_dates=['timestamp'])
df['date'] = df['timestamp'].dt.date

# Set Seaborn theme
sns.set(style='whitegrid')

# %% [markdown]
# ### Token Transfer Volume Distribution

# %%
plt.figure(figsize=(10, 6))

sns.histplot(df['amount'], bins=50, kde=True, color='skyblue')

plt.title('Distribution of Token Transfer Amounts')
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.xlim(0, 3000)
plt.show()

# %% [markdown]
# ### Daily Total Transfer

# %%
daily_volume = df.groupby('date')['amount'].sum().reset_index()

plt.figure(figsize=(12, 6))
sns.lineplot(data=daily_volume, x = 'date', y = 'amount', marker = 'o')
plt.title('Daily Total Token Transfer Volume')
plt.xlabel('Date')
plt.ylabel('Total Amount Transferred')
plt.tight_layout()
plt.show()
